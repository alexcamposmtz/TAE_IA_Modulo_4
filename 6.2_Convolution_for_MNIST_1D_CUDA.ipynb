# %% [markdown]
# # Talento Altamente Especializado (TAE) en Inteligencia Artificial
# ## Módulo 4 — Notebook 2.3: Deep Neural Networks
#
# **Nombre:** Alejandro Campos Martínez
# **Módulo:** 4
# **Programa:** Talento Altamente Especializado (TAE) en Inteligencia Artificial
# **Instructor:** German Alonso Pinedo Diaz
# **Lugar:** Tepic, Nayarit
# **Fecha:** 4 de julio de 2026
#
# ---

# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-q2z50xgm
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-q2z50xgm
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/xandro/anaconda3/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in /home/xandro/anaconda3/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (2.3.5)
# Requirement already satisfied: matplotlib in /home/xandro/anaconda3/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (3.10.6)
# Requirement already satisfied: scipy in /home/xandro/anaconda3/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/xandro/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/xandro/anaconda3/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/xandro/anaconda3/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/xandro/anaconda3/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/xandro/anaconda3/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

model = nn.Sequential(
  nn.Conv1d(1, 15, kernel_size=3, stride=2, padding="valid"),
  nn.ReLU(),
  nn.Conv1d(15, 15, kernel_size=3, stride=2, padding="valid"),
  nn.ReLU(),
  nn.Conv1d(15, 15, kernel_size=3, stride=2, padding="valid"),
  nn.ReLU(),
  nn.Flatten(),
  nn.Linear(60, 10))

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Detecta si hay GPU disponible (CUDA o MPS/Metal) y usa esa; si no, usa CPU
device = torch.device("cuda" if torch.cuda.is_available()
                       else "mps" if (hasattr(torch.backends, "mps") and torch.backends.mps.is_available())
                       else "cpu")
print(f"Usando dispositivo: {device}")
if device.type == "cuda":
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Mueve el modelo y los datos de validación/entrenamiento completos al dispositivo
model = model.to(device)
x_train = x_train.to(device)
y_train = y_train.to(device)
x_val = x_val.to(device)
y_val = y_val.to(device)

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote (ya están en el dispositivo, vienen de x_train/y_train)
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Usando dispositivo: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
# Epoch     0, training loss 2.134318, training error 76.78, validation loss 2.143562, validation error 77.90
# Epoch     1, training loss 1.597698, training error 62.50, validation loss 1.605763, validation error 63.90
# Epoch     2, training loss 1.391068, training error 58.72, validation loss 1.410268, validation error 60.60
# Epoch     3, training loss 1.255229, training error 51.52, validation loss 1.275807, validation error 53.60
# Epoch     4, training loss 1.297087, training error 50.87, validation loss 1.327412, validation error 52.70
# Epoch     5, training loss 1.098277, training error 44.60, validation loss 1.114317, validation error 44.50
# Epoch     6, training loss 0.960260, training error 38.45, validation loss 0.995610, validation error 41.90
# Epoch     7, training loss 0.839569, training error 34.07, validation loss 0.881682, validation error 36.10
# Epoch     8, training loss 0.807095, training error 31.85, validation loss 0.834898, validation error 32.70
# Epoch     9, training loss 0.682171, training error 26.80, validation loss 0.727383, validation error 28.90
# Epoch    10, training loss 0.656644, training error 25.22, validation loss 0.706358, validation error 25.50
# Epoch    11, training loss 0.619278, training error 23.25, validation loss 0.677332, validation error 26.30
# Epoch    12, training loss 0.607111, training error 22.72, validation loss 0.655955, validation error 24.30
# Epoch    13, training loss 0.487549, training error 17.67, validation loss 0.562401, validation error 20.50
# Epoch    14, training loss 0.405129, training error 13.95, validation loss 0.486701, validation error 16.30
# Epoch    15, training loss 0.366764, training error 13.57, validation loss 0.447192, validation error 16.30
# Epoch    16, training loss 0.253979, training error 8.15, validation loss 0.342492, validation error 11.50
# Epoch    17, training loss 0.251811, training error 8.62, validation loss 0.355449, validation error 12.60
# Epoch    18, training loss 0.346561, training error 12.72, validation loss 0.455426, validation error 16.30
# Epoch    19, training loss 0.253942, training error 8.75, validation loss 0.392777, validation error 12.50
# Epoch    20, training loss 0.136922, training error 4.85, validation loss 0.258806, validation error 8.60
# Epoch    21, training loss 0.132432, training error 4.60, validation loss 0.255180, validation error 8.80
# Epoch    22, training loss 0.123912, training error 3.95, validation loss 0.267921, validation error 9.90
# Epoch    23, training loss 0.115838, training error 3.85, validation loss 0.265865, validation error 9.00
# Epoch    24, training loss 0.117524, training error 3.95, validation loss 0.280277, validation error 10.00
# Epoch    25, training loss 0.106599, training error 3.47, validation loss 0.267232, validation error 10.00
# Epoch    26, training loss 0.103350, training error 3.27, validation loss 0.266730, validation error 8.10
# Epoch    27, training loss 0.088095, training error 2.85, validation loss 0.264392, validation error 8.40
# Epoch    28, training loss 0.083028, training error 2.45, validation loss 0.260183, validation error 8.80
# Epoch    29, training loss 0.079591, training error 2.45, validation loss 0.264603, validation error 7.90
# Epoch    30, training loss 0.079641, training error 2.50, validation loss 0.261637, validation error 9.10
# Epoch    31, training loss 0.079479, training error 2.52, validation loss 0.261936, validation error 8.60
# Epoch    32, training loss 0.072388, training error 2.02, validation loss 0.260516, validation error 8.40
# Epoch    33, training loss 0.085578, training error 2.97, validation loss 0.291274, validation error 9.80
# Epoch    34, training loss 0.086322, training error 2.77, validation loss 0.285756, validation error 10.10
# Epoch    35, training loss 0.068453, training error 2.20, validation loss 0.281884, validation error 8.90
# Epoch    36, training loss 0.061236, training error 1.92, validation loss 0.283935, validation error 9.40
# Epoch    37, training loss 0.056582, training error 1.45, validation loss 0.278105, validation error 8.50
# Epoch    38, training loss 0.052702, training error 1.55, validation loss 0.280573, validation error 8.70
# Epoch    39, training loss 0.065840, training error 2.20, validation loss 0.297971, validation error 8.50
# Epoch    40, training loss 0.045453, training error 1.15, validation loss 0.275465, validation error 8.50
# Epoch    41, training loss 0.040915, training error 1.05, validation loss 0.280191, validation error 8.50
# Epoch    42, training loss 0.039728, training error 0.90, validation loss 0.279043, validation error 8.30
# Epoch    43, training loss 0.039558, training error 0.90, validation loss 0.281672, validation error 8.70
# Epoch    44, training loss 0.042512, training error 1.17, validation loss 0.291924, validation error 8.60
# Epoch    45, training loss 0.039191, training error 0.90, validation loss 0.300678, validation error 8.10
# Epoch    46, training loss 0.041405, training error 1.15, validation loss 0.304861, validation error 8.70
# Epoch    47, training loss 0.037240, training error 0.87, validation loss 0.291836, validation error 8.70
# Epoch    48, training loss 0.034873, training error 0.62, validation loss 0.296057, validation error 8.50
# Epoch    49, training loss 0.034407, training error 0.70, validation loss 0.310350, validation error 8.40
# Epoch    50, training loss 0.032967, training error 0.62, validation loss 0.302815, validation error 8.40
# Epoch    51, training loss 0.032965, training error 0.70, validation loss 0.312924, validation error 8.70
# Epoch    52, training loss 0.038051, training error 1.02, validation loss 0.317970, validation error 8.40
# Epoch    53, training loss 0.029773, training error 0.52, validation loss 0.308166, validation error 7.90
# Epoch    54, training loss 0.028599, training error 0.42, validation loss 0.313976, validation error 8.60
# Epoch    55, training loss 0.033045, training error 0.57, validation loss 0.322657, validation error 8.40
# Epoch    56, training loss 0.027338, training error 0.35, validation loss 0.308294, validation error 8.10
# Epoch    57, training loss 0.029873, training error 0.60, validation loss 0.318186, validation error 8.50
# Epoch    58, training loss 0.026036, training error 0.30, validation loss 0.314727, validation error 8.50
# Epoch    59, training loss 0.025962, training error 0.30, validation loss 0.324684, validation error 8.50
# Epoch    60, training loss 0.024780, training error 0.35, validation loss 0.324169, validation error 8.40
# Epoch    61, training loss 0.024083, training error 0.25, validation loss 0.322023, validation error 8.50
# Epoch    62, training loss 0.023789, training error 0.30, validation loss 0.327166, validation error 8.60
# Epoch    63, training loss 0.023469, training error 0.22, validation loss 0.326871, validation error 8.60
# Epoch    64, training loss 0.022930, training error 0.20, validation loss 0.327881, validation error 8.50
# Epoch    65, training loss 0.022536, training error 0.17, validation loss 0.331195, validation error 8.30
# Epoch    66, training loss 0.022458, training error 0.20, validation loss 0.330803, validation error 8.50
# Epoch    67, training loss 0.022169, training error 0.22, validation loss 0.333662, validation error 8.40
# Epoch    68, training loss 0.021872, training error 0.20, validation loss 0.331777, validation error 8.40
# Epoch    69, training loss 0.021524, training error 0.17, validation loss 0.333275, validation error 8.80
# Epoch    70, training loss 0.021286, training error 0.20, validation loss 0.335605, validation error 8.80
# Epoch    71, training loss 0.022142, training error 0.25, validation loss 0.340226, validation error 8.10
# Epoch    72, training loss 0.020831, training error 0.17, validation loss 0.336912, validation error 8.50
# Epoch    73, training loss 0.020688, training error 0.17, validation loss 0.337905, validation error 8.70
# Epoch    74, training loss 0.020620, training error 0.22, validation loss 0.341938, validation error 8.00
# Epoch    75, training loss 0.020062, training error 0.17, validation loss 0.341281, validation error 8.50
# Epoch    76, training loss 0.020172, training error 0.12, validation loss 0.341082, validation error 8.50
# Epoch    77, training loss 0.019563, training error 0.17, validation loss 0.344611, validation error 8.20
# Epoch    78, training loss 0.020507, training error 0.22, validation loss 0.346488, validation error 8.20
# Epoch    79, training loss 0.019283, training error 0.17, validation loss 0.349190, validation error 8.40
# Epoch    80, training loss 0.018878, training error 0.17, validation loss 0.348219, validation error 8.40
# Epoch    81, training loss 0.018792, training error 0.15, validation loss 0.346810, validation error 8.70
# Epoch    82, training loss 0.018645, training error 0.17, validation loss 0.348002, validation error 8.70
# Epoch    83, training loss 0.018890, training error 0.17, validation loss 0.348894, validation error 8.30
# Epoch    84, training loss 0.018407, training error 0.17, validation loss 0.348768, validation error 8.60
# Epoch    85, training loss 0.018304, training error 0.17, validation loss 0.349054, validation error 8.60
# Epoch    86, training loss 0.018668, training error 0.12, validation loss 0.349778, validation error 8.70
# Epoch    87, training loss 0.018191, training error 0.15, validation loss 0.349599, validation error 8.60
# Epoch    88, training loss 0.018033, training error 0.17, validation loss 0.351047, validation error 8.70
# Epoch    89, training loss 0.017987, training error 0.12, validation loss 0.352307, validation error 8.50
# Epoch    90, training loss 0.018285, training error 0.10, validation loss 0.351346, validation error 8.70
# Epoch    91, training loss 0.017729, training error 0.12, validation loss 0.352835, validation error 8.60
# Epoch    92, training loss 0.017632, training error 0.12, validation loss 0.354323, validation error 8.60
# Epoch    93, training loss 0.017595, training error 0.15, validation loss 0.352896, validation error 8.70
# Epoch    94, training loss 0.017687, training error 0.10, validation loss 0.355057, validation error 8.70
# Epoch    95, training loss 0.017481, training error 0.10, validation loss 0.354600, validation error 8.70
# Epoch    96, training loss 0.017320, training error 0.10, validation loss 0.356012, validation error 8.70
# Epoch    97, training loss 0.017363, training error 0.07, validation loss 0.356310, validation error 8.60
# Epoch    98, training loss 0.017494, training error 0.12, validation loss 0.356866, validation error 8.70
# Epoch    99, training loss 0.017380, training error 0.10, validation loss 0.358028, validation error 8.40
