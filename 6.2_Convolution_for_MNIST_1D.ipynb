# %% [markdown]
# # Talento Altamente Especializado (TAE) en Inteligencia Artificial
# ## Módulo 4 — Notebook 2.3: Deep Neural Networks
#
# **Nombre:** Alejandro Campos Martínez
# **Módulo:** 4
# **Programa:** Talento Altamente Especializado (TAE) en Inteligencia Artificial
# **Instructor:** German Alonso Pinedo Diaz
# **Lugar:** Tepic, Nayarit
# **Fecha:** 4 de julio de 2026
#
# ---

# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-pp42n62p
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-pp42n62p
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/xandro/anaconda3/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in /home/xandro/anaconda3/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (2.3.5)
# Requirement already satisfied: matplotlib in /home/xandro/anaconda3/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (3.10.6)
# Requirement already satisfied: scipy in /home/xandro/anaconda3/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/xandro/anaconda3/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/xandro/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/xandro/anaconda3/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/xandro/anaconda3/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/xandro/anaconda3/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/xandro/anaconda3/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=15923 sha256=b0e9ba73bcc230db2214be84ee76b84ca4e9943d97952615c810c732aa86b326
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c_pj8aot/wheels/33/99/c5/794fea38f039adfbca82fd56e4a00b3e1e4533a808baee9910
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

model = nn.Sequential(
  nn.Conv1d(1, 15, kernel_size=3, stride=2, padding="valid"),
  nn.ReLU(),
  nn.Conv1d(15, 15, kernel_size=3, stride=2, padding="valid"),
  nn.ReLU(),
  nn.Conv1d(15, 15, kernel_size=3, stride=2, padding="valid"),
  nn.ReLU(),
  nn.Flatten(),
  nn.Linear(60, 10))

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 1.835099, training error 72.57, validation loss 1.840609, validation error 73.90
# Epoch     1, training loss 1.485865, training error 58.15, validation loss 1.500409, validation error 60.30
# Epoch     2, training loss 1.358030, training error 54.75, validation loss 1.360266, validation error 55.30
# Epoch     3, training loss 1.274765, training error 50.72, validation loss 1.276927, validation error 52.60
# Epoch     4, training loss 1.240590, training error 49.17, validation loss 1.292395, validation error 53.20
# Epoch     5, training loss 1.229815, training error 48.60, validation loss 1.242811, validation error 51.20
# Epoch     6, training loss 1.097383, training error 43.75, validation loss 1.122073, validation error 46.50
# Epoch     7, training loss 0.990228, training error 38.90, validation loss 1.029490, validation error 42.10
# Epoch     8, training loss 0.983418, training error 38.38, validation loss 1.034873, validation error 41.20
# Epoch     9, training loss 0.859828, training error 34.00, validation loss 0.883082, validation error 37.80
# Epoch    10, training loss 0.790305, training error 30.05, validation loss 0.825724, validation error 31.70
# Epoch    11, training loss 0.704008, training error 28.05, validation loss 0.771800, validation error 30.60
# Epoch    12, training loss 0.658780, training error 25.10, validation loss 0.729616, validation error 28.30
# Epoch    13, training loss 0.589247, training error 22.72, validation loss 0.672649, validation error 27.20
# Epoch    14, training loss 0.545221, training error 21.40, validation loss 0.630234, validation error 24.70
# Epoch    15, training loss 0.499495, training error 19.22, validation loss 0.581390, validation error 23.90
# Epoch    16, training loss 0.490363, training error 19.40, validation loss 0.593188, validation error 23.60
# Epoch    17, training loss 0.486059, training error 18.00, validation loss 0.576484, validation error 20.20
# Epoch    18, training loss 0.424547, training error 15.53, validation loss 0.530721, validation error 19.20
# Epoch    19, training loss 0.366799, training error 13.00, validation loss 0.460979, validation error 16.50
# Epoch    20, training loss 0.294060, training error 10.10, validation loss 0.426647, validation error 15.30
# Epoch    21, training loss 0.286355, training error 9.82, validation loss 0.424504, validation error 15.80
# Epoch    22, training loss 0.244968, training error 8.18, validation loss 0.390397, validation error 13.80
# Epoch    23, training loss 0.238607, training error 7.93, validation loss 0.395197, validation error 13.90
# Epoch    24, training loss 0.253052, training error 9.35, validation loss 0.436337, validation error 15.20
# Epoch    25, training loss 0.212203, training error 6.85, validation loss 0.378648, validation error 14.10
# Epoch    26, training loss 0.212325, training error 7.10, validation loss 0.378292, validation error 13.30
# Epoch    27, training loss 0.193349, training error 6.40, validation loss 0.352633, validation error 12.70
# Epoch    28, training loss 0.189097, training error 6.43, validation loss 0.383644, validation error 12.90
# Epoch    29, training loss 0.162501, training error 5.53, validation loss 0.353070, validation error 11.80
# Epoch    30, training loss 0.152131, training error 4.85, validation loss 0.358322, validation error 11.40
# Epoch    31, training loss 0.154256, training error 5.40, validation loss 0.369376, validation error 12.80
# Epoch    32, training loss 0.134654, training error 4.30, validation loss 0.340957, validation error 10.20
# Epoch    33, training loss 0.135939, training error 4.55, validation loss 0.335640, validation error 11.70
# Epoch    34, training loss 0.119196, training error 3.80, validation loss 0.339312, validation error 10.80
# Epoch    35, training loss 0.149230, training error 4.95, validation loss 0.354046, validation error 11.00
# Epoch    36, training loss 0.123164, training error 4.22, validation loss 0.354678, validation error 11.20
# Epoch    37, training loss 0.104162, training error 3.10, validation loss 0.312258, validation error 9.50
# Epoch    38, training loss 0.113739, training error 3.53, validation loss 0.339848, validation error 10.50
# Epoch    39, training loss 0.107716, training error 3.20, validation loss 0.326936, validation error 10.30
# Epoch    40, training loss 0.085931, training error 2.38, validation loss 0.313588, validation error 10.50
# Epoch    41, training loss 0.079484, training error 2.07, validation loss 0.324735, validation error 10.70
# Epoch    42, training loss 0.075200, training error 2.03, validation loss 0.320339, validation error 9.50
# Epoch    43, training loss 0.072228, training error 1.78, validation loss 0.330180, validation error 10.10
# Epoch    44, training loss 0.075189, training error 1.80, validation loss 0.327619, validation error 10.40
# Epoch    45, training loss 0.069337, training error 1.75, validation loss 0.326818, validation error 10.10
# Epoch    46, training loss 0.068123, training error 1.70, validation loss 0.333057, validation error 9.30
# Epoch    47, training loss 0.073008, training error 1.88, validation loss 0.336960, validation error 10.30
# Epoch    48, training loss 0.065762, training error 1.55, validation loss 0.343280, validation error 10.30
# Epoch    49, training loss 0.061631, training error 1.55, validation loss 0.334587, validation error 9.70
# Epoch    50, training loss 0.059697, training error 1.25, validation loss 0.338228, validation error 9.90
# Epoch    51, training loss 0.057858, training error 1.20, validation loss 0.342718, validation error 9.90
# Epoch    52, training loss 0.061842, training error 1.50, validation loss 0.354394, validation error 10.40
# Epoch    53, training loss 0.064754, training error 1.85, validation loss 0.363509, validation error 10.20
# Epoch    54, training loss 0.059698, training error 1.45, validation loss 0.361998, validation error 10.20
# Epoch    55, training loss 0.057308, training error 1.45, validation loss 0.353882, validation error 10.40
# Epoch    56, training loss 0.052783, training error 1.18, validation loss 0.350600, validation error 10.30
# Epoch    57, training loss 0.052746, training error 1.05, validation loss 0.334884, validation error 10.10
# Epoch    58, training loss 0.050999, training error 1.10, validation loss 0.351631, validation error 10.00
# Epoch    59, training loss 0.047892, training error 1.00, validation loss 0.358409, validation error 10.40
# Epoch    60, training loss 0.047224, training error 1.07, validation loss 0.354636, validation error 10.10
# Epoch    61, training loss 0.045114, training error 0.82, validation loss 0.353321, validation error 10.40
# Epoch    62, training loss 0.045196, training error 0.90, validation loss 0.359467, validation error 10.60
# Epoch    63, training loss 0.043759, training error 0.68, validation loss 0.359576, validation error 10.40
# Epoch    64, training loss 0.042789, training error 0.78, validation loss 0.358755, validation error 10.50
# Epoch    65, training loss 0.043478, training error 0.82, validation loss 0.364011, validation error 10.20
# Epoch    66, training loss 0.041321, training error 0.65, validation loss 0.360422, validation error 10.30
# Epoch    67, training loss 0.041866, training error 0.70, validation loss 0.360741, validation error 10.30
# Epoch    68, training loss 0.041475, training error 0.75, validation loss 0.365903, validation error 10.00
# Epoch    69, training loss 0.040136, training error 0.65, validation loss 0.363489, validation error 10.00
# Epoch    70, training loss 0.040548, training error 0.65, validation loss 0.365886, validation error 9.90
# Epoch    71, training loss 0.039712, training error 0.68, validation loss 0.362953, validation error 9.80
# Epoch    72, training loss 0.038838, training error 0.60, validation loss 0.368075, validation error 9.90
# Epoch    73, training loss 0.038697, training error 0.57, validation loss 0.364556, validation error 10.40
# Epoch    74, training loss 0.038109, training error 0.60, validation loss 0.369355, validation error 10.00
# Epoch    75, training loss 0.037831, training error 0.60, validation loss 0.371227, validation error 10.30
# Epoch    76, training loss 0.037737, training error 0.50, validation loss 0.369691, validation error 10.20
# Epoch    77, training loss 0.036689, training error 0.53, validation loss 0.372620, validation error 9.70
# Epoch    78, training loss 0.036640, training error 0.53, validation loss 0.371368, validation error 9.90
# Epoch    79, training loss 0.036225, training error 0.57, validation loss 0.374768, validation error 10.30
# Epoch    80, training loss 0.035189, training error 0.47, validation loss 0.372169, validation error 10.10
# Epoch    81, training loss 0.035175, training error 0.45, validation loss 0.375865, validation error 10.20
# Epoch    82, training loss 0.036444, training error 0.50, validation loss 0.377663, validation error 9.90
# Epoch    83, training loss 0.034760, training error 0.47, validation loss 0.375058, validation error 9.90
# Epoch    84, training loss 0.035698, training error 0.60, validation loss 0.375780, validation error 9.90
# Epoch    85, training loss 0.034631, training error 0.50, validation loss 0.378131, validation error 10.20
# Epoch    86, training loss 0.034372, training error 0.45, validation loss 0.379519, validation error 10.10
# Epoch    87, training loss 0.034222, training error 0.50, validation loss 0.377933, validation error 10.00
# Epoch    88, training loss 0.033524, training error 0.47, validation loss 0.377042, validation error 10.00
# Epoch    89, training loss 0.033298, training error 0.47, validation loss 0.377142, validation error 10.00
# Epoch    90, training loss 0.033152, training error 0.43, validation loss 0.377739, validation error 9.90
# Epoch    91, training loss 0.033072, training error 0.45, validation loss 0.380790, validation error 10.00
# Epoch    92, training loss 0.033516, training error 0.47, validation loss 0.381315, validation error 10.10
# Epoch    93, training loss 0.032611, training error 0.50, validation loss 0.380760, validation error 10.10
# Epoch    94, training loss 0.032671, training error 0.43, validation loss 0.381328, validation error 10.30
# Epoch    95, training loss 0.032822, training error 0.50, validation loss 0.381841, validation error 10.00
# Epoch    96, training loss 0.032086, training error 0.45, validation loss 0.382054, validation error 10.20
# Epoch    97, training loss 0.032380, training error 0.43, validation loss 0.381665, validation error 9.90
# Epoch    98, training loss 0.032039, training error 0.45, validation loss 0.382302, validation error 10.20
# Epoch    99, training loss 0.031566, training error 0.38, validation loss 0.382841, validation error 9.90
