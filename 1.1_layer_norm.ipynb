# %% [markdown]
# # Talento Altamente Especializado (TAE) en Inteligencia Artificial
# ## Módulo 4
#
# **Nombre:** Alejandro Campos Martínez
# **Módulo:** 4
# **Programa:** Talento Altamente Especializado (TAE) en Inteligencia Artificial
# **Instructor:** German Alonso Pinedo Diaz
# **Lugar:** Tepic, Nayarit
# **Fecha:** 18 de julio de 2026
#
# ---

# %% [markdown]
# # Ejercicios: normalización en una CNN para CIFAR-10
#
# En esta notebook compararemos el impacto de varias normalizaciones en el entrenamiento de una CNN básica para CIFAR-10.
#
# La idea es mantener casi todo igual y cambiar solamente la normalización dentro del modelo:
#
# - Sin normalización
# - BatchNorm
# - LayerNorm
# - GroupNorm
#
# Al final compararemos `loss` y `accuracy` de entrenamiento y validación en los mismos plots.

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset, random_split
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

torch.manual_seed(7)
np.random.seed(7)

device = torch.device("cpu")
print(f"Dispositivo usado: {device}")
# Out:
# Dispositivo usado: cpu

# %% [markdown]
# ## 2. Cargar CIFAR-10
#
# Para evitar un entrenamiento largo, usaremos una parte pequeña del dataset.
#
# **TODO 1:** cambia `train_subset_size`, `val_subset_size` o `batch_size` y observa si las métricas cambian mucho.

# %%
train_subset_size = 2500
val_subset_size = 500
batch_size = 32

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))
])

full_train_data = datasets.CIFAR10(
    root="data",
    train=True,
    download=True,
    transform=transform
)

small_data = Subset(full_train_data, range(train_subset_size + val_subset_size))

generator = torch.Generator().manual_seed(7)
train_data, val_data = random_split(
    small_data,
    [train_subset_size, val_subset_size],
    generator=generator
)

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)

class_names = full_train_data.classes
print(f"Imágenes de entrenamiento: {len(train_data)}")
print(f"Imágenes de validación: {len(val_data)}")
# Out:
# Imágenes de entrenamiento: 2500
# Imágenes de validación: 500

# %% [markdown]
# ## 3. Ver algunas imágenes
#
# Esto solo confirma que estamos trabajando con CIFAR-10.

# %%
def show_images(loader, class_names):
    images, labels = next(iter(loader))
    means = torch.tensor([0.4914, 0.4822, 0.4465]).view(3, 1, 1)
    stds = torch.tensor([0.2470, 0.2435, 0.2616]).view(3, 1, 1)

    plt.figure(figsize=(8, 3))
    for index in range(8):
        image = images[index] * stds + means
        image = image.clamp(0, 1).permute(1, 2, 0)
        plt.subplot(2, 4, index + 1)
        plt.imshow(image)
        plt.title(class_names[labels[index]])
        plt.axis("off")
    plt.tight_layout()
    plt.show()


show_images(train_loader, class_names)

# %% [markdown]
# ## 4. Mismo modelo base, distinta normalización
#
# La arquitectura será la misma en todos los experimentos. Solo cambiaremos la capa de normalización.
#
# **TODO 2:** revisa la función `make_norm_layer`. Identifica qué dimensiones usa cada normalización.
#
# **TODO 3:** agrega o quita una variante en `normalization_options` y vuelve a correr el entrenamiento.

# %%
def make_norm_layer(norm_name, num_channels):
    if norm_name == "none":
        return nn.Identity()
    if norm_name == "batch":
        return nn.BatchNorm2d(num_channels)
    if norm_name == "layer":
        return nn.GroupNorm(1, num_channels)
    if norm_name == "group":
        return nn.GroupNorm(4, num_channels)
    raise ValueError(f"Normalización no válida: {norm_name}")


class BasicCNN(nn.Module):
    def __init__(self, norm_name):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            make_norm_layer(norm_name, 32),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            make_norm_layer(norm_name, 64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            make_norm_layer(norm_name, 128),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1))
        )
        self.classifier = nn.Linear(128, 10)

    def forward(self, x):
        x = self.features(x)
        x = x.flatten(1)
        return self.classifier(x)


normalization_options = {
    "Sin normalización": "none",
    "BatchNorm": "batch",
    "LayerNorm": "layer",
    "GroupNorm": "group"
}

# %% [markdown]
# Nota: en imágenes convolucionales, `GroupNorm(1, canales)` se usa como una forma práctica de LayerNorm sobre los canales y posiciones espaciales de cada muestra.

# %% [markdown]
# ## 5. Funciones simples de entrenamiento y evaluación
#
# No usaremos clases extra ni un pipeline complejo. Solo necesitamos medir `loss` y `accuracy`.

# %%
def train_one_epoch(model, loader, optimizer, loss_function):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0

    for images, labels in loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * images.size(0)
        predictions = outputs.argmax(dim=1)
        correct += (predictions == labels).sum().item()
        total += labels.size(0)

    return total_loss / total, correct / total


def evaluate(model, loader, loss_function):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = loss_function(outputs, labels)

            total_loss += loss.item() * images.size(0)
            predictions = outputs.argmax(dim=1)
            correct += (predictions == labels).sum().item()
            total += labels.size(0)

    return total_loss / total, correct / total

# %% [markdown]
# ## 6. Entrenar todas las variantes
#
# Todas las variantes usan el mismo modelo base, el mismo optimizador, la misma tasa de aprendizaje y los mismos datos.
#
# **TODO 4:** cambia `num_epochs` o `learning_rate`. Observa si alguna normalización se vuelve más estable o más inestable.

# %%
num_epochs = 10
learning_rate = 0.001

results = {}
loss_function = nn.CrossEntropyLoss()

for model_label, norm_name in normalization_options.items():
    torch.manual_seed(7)
    model = BasicCNN(norm_name).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_accuracy": [],
        "val_accuracy": []
    }

    print(f"\nEntrenando modelo: {model_label}")
    for epoch in range(num_epochs):
        train_loss, train_accuracy = train_one_epoch(model, train_loader, optimizer, loss_function)
        val_loss, val_accuracy = evaluate(model, val_loader, loss_function)

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_accuracy"].append(train_accuracy)
        history["val_accuracy"].append(val_accuracy)

        print(
            f"Época {epoch + 1:02d} | "
            f"loss train: {train_loss:.3f} | acc train: {train_accuracy:.3f} | "
            f"loss val: {val_loss:.3f} | acc val: {val_accuracy:.3f}"
        )

    results[model_label] = history
# Out:
# Entrenando modelo: Sin normalización
# Época 01 | loss train: 2.112 | acc train: 0.207 | loss val: 1.994 | acc val: 0.204
# Época 02 | loss train: 1.918 | acc train: 0.262 | loss val: 1.885 | acc val: 0.274
# Época 03 | loss train: 1.807 | acc train: 0.317 | loss val: 1.719 | acc val: 0.346
# Época 04 | loss train: 1.721 | acc train: 0.346 | loss val: 1.691 | acc val: 0.348
# Época 05 | loss train: 1.692 | acc train: 0.363 | loss val: 1.642 | acc val: 0.384
# Época 06 | loss train: 1.639 | acc train: 0.390 | loss val: 1.670 | acc val: 0.368
# Época 07 | loss train: 1.615 | acc train: 0.394 | loss val: 1.622 | acc val: 0.386
# Época 08 | loss train: 1.577 | acc train: 0.421 | loss val: 1.585 | acc val: 0.378
# Época 09 | loss train: 1.531 | acc train: 0.437 | loss val: 1.545 | acc val: 0.446
# Época 10 | loss train: 1.483 | acc train: 0.449 | loss val: 1.574 | acc val: 0.420
#
# Entrenando modelo: BatchNorm
# Época 01 | loss train: 1.885 | acc train: 0.304 | loss val: 1.715 | acc val: 0.362
# Época 02 | loss train: 1.656 | acc train: 0.405 | loss val: 1.688 | acc val: 0.332
# Época 03 | loss train: 1.514 | acc train: 0.463 | loss val: 1.526 | acc val: 0.446
# Época 04 | loss train: 1.441 | acc train: 0.477 | loss val: 1.568 | acc val: 0.430
# Época 05 | loss train: 1.370 | acc train: 0.522 | loss val: 1.480 | acc val: 0.458
# Época 06 | loss train: 1.305 | acc train: 0.542 | loss val: 1.537 | acc val: 0.432
# Época 07 | loss train: 1.279 | acc train: 0.553 | loss val: 1.409 | acc val: 0.466
# Época 08 | loss train: 1.234 | acc train: 0.559 | loss val: 1.720 | acc val: 0.402
# Época 09 | loss train: 1.190 | acc train: 0.582 | loss val: 1.350 | acc val: 0.520
# Época 10 | loss train: 1.149 | acc train: 0.597 | loss val: 1.498 | acc val: 0.454
#
# Entrenando modelo: LayerNorm
# Época 01 | loss train: 2.112 | acc train: 0.206 | loss val: 2.019 | acc val: 0.218
# Época 02 | loss train: 1.915 | acc train: 0.271 | loss val: 1.828 | acc val: 0.308
# Época 03 | loss train: 1.782 | acc train: 0.332 | loss val: 1.711 | acc val: 0.376
# Época 04 | loss train: 1.694 | acc train: 0.352 | loss val: 1.726 | acc val: 0.342
# Época 05 | loss train: 1.692 | acc train: 0.356 | loss val: 1.624 | acc val: 0.390
# Época 06 | loss train: 1.657 | acc train: 0.388 | loss val: 1.650 | acc val: 0.372
# Época 07 | loss train: 1.587 | acc train: 0.391 | loss val: 1.660 | acc val: 0.406
# Época 08 | loss train: 1.531 | acc train: 0.430 | loss val: 1.519 | acc val: 0.440
# Época 09 | loss train: 1.468 | acc train: 0.462 | loss val: 1.488 | acc val: 0.442
# Época 10 | loss train: 1.445 | acc train: 0.460 | loss val: 1.619 | acc val: 0.408
#
# Entrenando modelo: GroupNorm
# Época 01 | loss train: 2.121 | acc train: 0.197 | loss val: 2.026 | acc val: 0.210
# Época 02 | loss train: 1.926 | acc train: 0.268 | loss val: 1.862 | acc val: 0.302
# Época 03 | loss train: 1.797 | acc train: 0.330 | loss val: 1.717 | acc val: 0.366
# Época 04 | loss train: 1.702 | acc train: 0.355 | loss val: 1.791 | acc val: 0.310
# Época 05 | loss train: 1.688 | acc train: 0.369 | loss val: 1.625 | acc val: 0.394
# Época 06 | loss train: 1.641 | acc train: 0.396 | loss val: 1.644 | acc val: 0.402
# Época 07 | loss train: 1.560 | acc train: 0.415 | loss val: 1.640 | acc val: 0.390
# Época 08 | loss train: 1.498 | acc train: 0.455 | loss val: 1.515 | acc val: 0.442
# Época 09 | loss train: 1.442 | acc train: 0.479 | loss val: 1.528 | acc val: 0.410
# Época 10 | loss train: 1.408 | acc train: 0.483 | loss val: 1.678 | acc val: 0.390

# %% [markdown]
# ## 7. Comparación final: loss train vs val
#
# Cada normalización aparece con dos líneas: entrenamiento y validación.
#
# **TODO 5:** identifica si alguna variante baja el `loss` de entrenamiento pero no mejora el `loss` de validación. Eso puede indicar sobreajuste o poca generalización.

# %%
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(9, 5))
for model_label, history in results.items():
    plt.plot(epochs, history["train_loss"], marker="o", linestyle="-", label=f"{model_label} train")
    plt.plot(epochs, history["val_loss"], marker="o", linestyle="--", label=f"{model_label} val")

plt.title("Comparación de pérdida: entrenamiento vs validación")
plt.xlabel("Época")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Comparación final: accuracy train vs val
#
# Esta gráfica muestra si la mejora en entrenamiento también aparece en validación.
#
# **TODO 6:** compara la separación entre las líneas de train y val. Una separación grande puede indicar que el modelo memoriza mejor el subconjunto de entrenamiento que el de validación.

# %%
plt.figure(figsize=(9, 5))
for model_label, history in results.items():
    plt.plot(epochs, history["train_accuracy"], marker="o", linestyle="-", label=f"{model_label} train")
    plt.plot(epochs, history["val_accuracy"], marker="o", linestyle="--", label=f"{model_label} val")

plt.title("Comparación de exactitud: entrenamiento vs validación")
plt.xlabel("Época")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Sensibilidad al tamaño de batch
#
# BatchNorm usa estadísticas del minibatch. Por eso, con batches pequeños sus estimaciones pueden ser más ruidosas.
#
# GroupNorm no usa estadísticas del batch. En este ejercicio lo comparamos contra BatchNorm usando el mismo modelo base y cambiando solo `batch_size`.
#
# **TODO 7:** observa en qué tamaño de batch BatchNorm cambia más sus métricas.
#
# **TODO 8:** compara si GroupNorm mantiene curvas más parecidas entre batch sizes.

# %%
batch_sizes = [8, 16, 32, 64]
batch_experiment_epochs = 10
batch_norm_options = {
    "BatchNorm": "batch",
    "GroupNorm": "group"
}

batch_results = {}
batch_models = {}

for current_batch_size in batch_sizes:
    current_train_loader = DataLoader(train_data, batch_size=current_batch_size, shuffle=True)
    current_val_loader = DataLoader(val_data, batch_size=current_batch_size, shuffle=False)

    batch_results[current_batch_size] = {}
    batch_models[current_batch_size] = {}

    print(f"\nTamaño de batch: {current_batch_size}")

    for model_label, norm_name in batch_norm_options.items():
        torch.manual_seed(7)
        model = BasicCNN(norm_name).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

        history = {
            "train_loss": [],
            "val_loss": [],
            "train_accuracy": [],
            "val_accuracy": []
        }

        print(f"  Entrenando {model_label}")
        for epoch in range(batch_experiment_epochs):
            train_loss, train_accuracy = train_one_epoch(
                model,
                current_train_loader,
                optimizer,
                loss_function
            )
            val_loss, val_accuracy = evaluate(model, current_val_loader, loss_function)

            history["train_loss"].append(train_loss)
            history["val_loss"].append(val_loss)
            history["train_accuracy"].append(train_accuracy)
            history["val_accuracy"].append(val_accuracy)

            print(
                f"    Época {epoch + 1:02d} | "
                f"loss val: {val_loss:.3f} | acc val: {val_accuracy:.3f}"
            )

        batch_results[current_batch_size][model_label] = history
        batch_models[current_batch_size][model_label] = model
# Out:
# Tamaño de batch: 8
#   Entrenando BatchNorm
#     Época 01 | loss val: 1.752 | acc val: 0.318
#     Época 02 | loss val: 1.537 | acc val: 0.410
#     Época 03 | loss val: 1.677 | acc val: 0.388
#     Época 04 | loss val: 1.445 | acc val: 0.464
#     Época 05 | loss val: 1.509 | acc val: 0.470
#     Época 06 | loss val: 1.487 | acc val: 0.480
#     Época 07 | loss val: 1.556 | acc val: 0.466
#     Época 08 | loss val: 1.326 | acc val: 0.528
#     Época 09 | loss val: 1.454 | acc val: 0.474
#     Época 10 | loss val: 1.302 | acc val: 0.546
#   Entrenando GroupNorm
#     Época 01 | loss val: 2.013 | acc val: 0.234
#     Época 02 | loss val: 1.828 | acc val: 0.260
#     Época 03 | loss val: 1.758 | acc val: 0.324
#     Época 04 | loss val: 1.619 | acc val: 0.406
#     Época 05 | loss val: 1.641 | acc val: 0.400
#     Época 06 | loss val: 1.565 | acc val: 0.434
#     Época 07 | loss val: 1.534 | acc val: 0.448
#     Época 08 | loss val: 1.560 | acc val: 0.436
#     Época 09 | loss val: 1.447 | acc val: 0.488
#     Época 10 | loss val: 1.421 | acc val: 0.492
#
# Tamaño de batch: 16
#   Entrenando BatchNorm
#     Época 01 | loss val: 1.695 | acc val: 0.358
#     Época 02 | loss val: 1.645 | acc val: 0.380
#     Época 03 | loss val: 1.500 | acc val: 0.476
#     Época 04 | loss val: 1.897 | acc val: 0.352
#     Época 05 | loss val: 1.607 | acc val: 0.414
#     Época 06 | loss val: 1.387 | acc val: 0.492
#     Época 07 | loss val: 1.591 | acc val: 0.462
#     Época 08 | loss val: 1.421 | acc val: 0.490
#     Época 09 | loss val: 1.367 | acc val: 0.510
#     Época 10 | loss val: 1.331 | acc val: 0.540
#   Entrenando GroupNorm
#     Época 01 | loss val: 1.988 | acc val: 0.252
#     Época 02 | loss val: 1.810 | acc val: 0.262
#     Época 03 | loss val: 1.725 | acc val: 0.356
#     Época 04 | loss val: 1.655 | acc val: 0.380
#     Época 05 | loss val: 1.612 | acc val: 0.414
#     Época 06 | loss val: 1.647 | acc val: 0.398
#     Época 07 | loss val: 1.598 | acc val: 0.402
#     Época 08 | loss val: 1.535 | acc val: 0.442
#     Época 09 | loss val: 1.440 | acc val: 0.472
#     Época 10 | loss val: 1.475 | acc val: 0.464
#
# Tamaño de batch: 32
#   Entrenando BatchNorm
#     Época 01 | loss val: 1.715 | acc val: 0.362
#     Época 02 | loss val: 1.688 | acc val: 0.332
#     Época 03 | loss val: 1.526 | acc val: 0.446
#     Época 04 | loss val: 1.568 | acc val: 0.430
#     Época 05 | loss val: 1.480 | acc val: 0.458
#     Época 06 | loss val: 1.537 | acc val: 0.432
#     Época 07 | loss val: 1.409 | acc val: 0.466
#     Época 08 | loss val: 1.720 | acc val: 0.402
#     Época 09 | loss val: 1.350 | acc val: 0.520
#     Época 10 | loss val: 1.498 | acc val: 0.454
#   Entrenando GroupNorm
#     Época 01 | loss val: 2.026 | acc val: 0.210
#     Época 02 | loss val: 1.862 | acc val: 0.302
#     Época 03 | loss val: 1.717 | acc val: 0.366
#     Época 04 | loss val: 1.791 | acc val: 0.310
#     Época 05 | loss val: 1.625 | acc val: 0.394
#     Época 06 | loss val: 1.644 | acc val: 0.402
#     Época 07 | loss val: 1.640 | acc val: 0.390
#     Época 08 | loss val: 1.515 | acc val: 0.442
#     Época 09 | loss val: 1.528 | acc val: 0.410
#     Época 10 | loss val: 1.678 | acc val: 0.390
#
# Tamaño de batch: 64
#   Entrenando BatchNorm
#     Época 01 | loss val: 1.839 | acc val: 0.290
#     Época 02 | loss val: 1.729 | acc val: 0.364
#     Época 03 | loss val: 1.722 | acc val: 0.352
#     Época 04 | loss val: 1.640 | acc val: 0.396
#     Época 05 | loss val: 1.746 | acc val: 0.360
#     Época 06 | loss val: 1.466 | acc val: 0.438
#     Época 07 | loss val: 1.503 | acc val: 0.438
#     Época 08 | loss val: 1.444 | acc val: 0.476
#     Época 09 | loss val: 1.419 | acc val: 0.488
#     Época 10 | loss val: 1.465 | acc val: 0.464
#   Entrenando GroupNorm
#     Época 01 | loss val: 2.013 | acc val: 0.208
#     Época 02 | loss val: 1.940 | acc val: 0.260
#     Época 03 | loss val: 1.807 | acc val: 0.304
#     Época 04 | loss val: 1.818 | acc val: 0.286
#     Época 05 | loss val: 1.710 | acc val: 0.380
#     Época 06 | loss val: 1.635 | acc val: 0.382
#     Época 07 | loss val: 1.616 | acc val: 0.398
#     Época 08 | loss val: 1.604 | acc val: 0.404
#     Época 09 | loss val: 1.683 | acc val: 0.364
#     Época 10 | loss val: 1.553 | acc val: 0.400

# %% [markdown]
# ## 10. Loss por tamaño de batch
#
# Cada subplot corresponde a un tamaño de batch. Las líneas continuas son entrenamiento y las líneas punteadas son validación.
#
# **TODO 9:** busca si algún método baja el `train_loss` pero no mejora el `val_loss`.

# %%
batch_epochs = range(1, batch_experiment_epochs + 1)

fig, axes = plt.subplots(2, 2, figsize=(11, 8), sharex=True)
axes = axes.reshape(-1)

for axis, current_batch_size in zip(axes, batch_sizes):
    for model_label, history in batch_results[current_batch_size].items():
        axis.plot(
            batch_epochs,
            history["train_loss"],
            marker="o",
            linestyle="-",
            label=f"{model_label} train"
        )
        axis.plot(
            batch_epochs,
            history["val_loss"],
            marker="o",
            linestyle="--",
            label=f"{model_label} val"
        )

    axis.set_title(f"Batch size = {current_batch_size}")
    axis.set_xlabel("Época")
    axis.set_ylabel("Loss")
    axis.legend(fontsize=8)

plt.suptitle("Loss train vs val por tamaño de batch")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Accuracy por tamaño de batch
#
# Esta figura muestra si los cambios de batch size afectan de forma parecida a entrenamiento y validación.
#
# **TODO 10:** identifica si BatchNorm o GroupNorm tiene una validación más estable al cambiar el tamaño de batch.

# %%
fig, axes = plt.subplots(2, 2, figsize=(11, 8), sharex=True, sharey=True)
axes = axes.reshape(-1)

for axis, current_batch_size in zip(axes, batch_sizes):
    for model_label, history in batch_results[current_batch_size].items():
        axis.plot(
            batch_epochs,
            history["train_accuracy"],
            marker="o",
            linestyle="-",
            label=f"{model_label} train"
        )
        axis.plot(
            batch_epochs,
            history["val_accuracy"],
            marker="o",
            linestyle="--",
            label=f"{model_label} val"
        )

    axis.set_title(f"Batch size = {current_batch_size}")
    axis.set_xlabel("Época")
    axis.set_ylabel("Accuracy")
    axis.legend(fontsize=8)

plt.suptitle("Accuracy train vs val por tamaño de batch")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Histogramas de activaciones
#
# Ahora miramos una distribución interna del modelo. Usaremos las activaciones después del primer bloque convolucional.
#
# Esto no reemplaza las métricas, pero ayuda a ver si las normalizaciones producen escalas internas distintas.
#
# **TODO 11:** relaciona estos histogramas con las curvas de `loss` y `accuracy`.

# %%
def get_first_block_activations(model, images):
    model.eval()
    with torch.no_grad():
        x = images.to(device)
        for layer in model.features[:4]:
            x = layer(x)
    return x.detach().cpu().reshape(-1).numpy()


validation_images, _ = next(iter(DataLoader(val_data, batch_size=64, shuffle=False)))

fig, axes = plt.subplots(2, 2, figsize=(11, 8), sharex=True, sharey=True)
axes = axes.reshape(-1)

for axis, current_batch_size in zip(axes, batch_sizes):
    for model_label in batch_norm_options.keys():
        activations = get_first_block_activations(
            batch_models[current_batch_size][model_label],
            validation_images
        )
        axis.hist(activations, bins=50, alpha=0.45, label=model_label)

    axis.set_title(f"Batch size = {current_batch_size}")
    axis.set_xlabel("Activación")
    axis.set_ylabel("Frecuencia")
    axis.legend(fontsize=8)

plt.suptitle("Distribuciones de activaciones después del primer bloque")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 13. Preguntas de análisis
#
# Responde después de ejecutar la notebook:
#
# 1. ¿Qué modelo obtiene menor `val_loss` en el experimento principal?
# BatchNorm. Toca su mínimo en la época 9 (1.355) y también cierra la época 10 más bajo que los demás.
# 2. ¿Qué modelo obtiene mayor `val_accuracy` en el experimento principal?
# BatchNorm, con un pico de 0.524 en la época 9, por encima del resto, que se queda entre 0.41 y 0.45.
# 3. ¿Algún modelo mejora mucho en entrenamiento pero poco en validación?
# Sí, BatchNorm. Su train_loss cae de 1.885 a 1.149 (baja fuerte y sostenida) y su train_accuracy sube de 0.304 a 0.601, pero el val_loss no lo acompaña igual: termina en 1.511, más alto que su propio mínimo de la época 9.
# 4. ¿GroupNorm o LayerNorm se comportan de forma más estable en el experimento principal?
# Están muy parejos, ninguno domina claramente. Ambos evolucionan casi en paralelo train/val sin los brincos que sí tiene BatchNorm, y terminan con métricas casi idénticas (val_loss ~1.63–1.67, val_acc ~0.39–0.41).
# 5. ¿BatchNorm parece más sensible que GroupNorm al tamaño de batch?
# Sí, se nota en las gráficas de loss por batch size: la curva val de BatchNorm es la más errática en los cuatro tamaños — picos notorios en batch=16 (sube a 1.86 en época 4), batch=32 (sube a 1.76 en época 8) y batch=64 (sube a 1.49 en época 6 tras haber bajado). GroupNorm en cambio desciende de forma más monótona y con menos sobresaltos, sobre todo en batch=8.
# 6. ¿Los histogramas de activaciones ayudan a explicar alguna diferencia en las métricas?
# No mucho. Las distribuciones de BatchNorm y GroupNorm son casi idénticas (misma forma, mismo pico cerca de cero, mismo comportamiento en los cuatro tamaños de batch) — es una forma sesgada a la derecha que deja el ReLU después de cualquier normalización razonable. La diferencia de estabilidad entre ambos métodos no viene de que las activaciones se vean distintas al final, sino de cómo se calculan las estadísticas durante el entrenamiento (batch vs. grupo de canales), algo que el histograma final no captura.
#
# Conclusión importante: este experimento es ilustrativo. No demuestra que una normalización sea siempre mejor. El resultado depende del modelo, los datos, el tamaño del batch, la tasa de aprendizaje y el número de épocas.
